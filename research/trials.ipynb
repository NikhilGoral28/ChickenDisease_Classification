# %%
d = {
    "key":"value",
    "key1":"value1"
}

# %%
d["key"]
# Out:
# 'value'

# %%
d.keys()

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(d)

# %%
d2.key
# Out:
# 'value'

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(num2:int, y:int) -> int:
    return num2*y

# %%
get_product(num2=3,y=5)
# Out:
# 15

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(num2:int, y:int) -> int:
    return num2*y

# %%
get_product(num2=3,y=3)
# Out:
# 9
